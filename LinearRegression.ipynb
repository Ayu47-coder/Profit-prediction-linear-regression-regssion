# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
data = r'C:\machine learning\50_Startups (2).csv'

df = pd.read_csv(data)
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
# Create the figure object
ax = df.groupby(['State'])['R&D Spend'].mean().plot.bar()

# Set the title
ax.set_title("Average profit for different states where the startups operate", fontsize = 20)

# Set x and y-labels
ax.set_xlabel("State", fontsize = 15)
ax.set_ylabel("R&D Spend", fontsize = 15)
# Out:
# Text(0, 0.5, 'R&D Spend')

# %%
# Create the figure object
ax = df.groupby(['State'])['Administration'].mean().plot.bar()

# Set the title
ax.set_title("Average profit for different states where the startups operate", fontsize = 20)

# Set x and y-labels
ax.set_xlabel("State", fontsize = 15)
ax.set_ylabel("Administration", fontsize = 15)
# Out:
# Text(0, 0.5, 'Administration')

# %%
# Create the figure object
ax = df.groupby(['State'])['Marketing Spend'].mean().plot.bar()

# Set the title
ax.set_title("Average profit for different states where the startups operate", fontsize = 20)

# Set x and y-labels
ax.set_xlabel("State", fontsize = 15)
ax.set_ylabel("marketing spend", fontsize = 15)
# Out:
# Text(0, 0.5, 'marketing spend')

# %%
# Create the figure object
ax = df.groupby(['State'])['Profit'].mean().plot.bar()

# Set the title
ax.set_title("Average profit for different states where the startups operate", fontsize = 20)

# Set x and y-labels
ax.set_xlabel("State", fontsize = 15)
ax.set_ylabel("Profit", fontsize = 15)
# Out:
# Text(0, 0.5, 'Profit')

# %%
expences = df.groupby('State')[['R&D Spend','Marketing Spend','Administration','Profit']].sum().sum()
expences
# Out:
# R&D Spend           3686080.78
# Marketing Spend    10551254.89
# Administration      6067231.98
# Profit              5600631.96
# dtype: float64

# %%
df.groupby('State')[['R&D Spend','Marketing Spend','Administration','Profit']].sum()
# Out:
#              R&D Spend  Marketing Spend  Administration      Profit
# State
# California  1099180.46       3103195.80      2052690.62  1766387.98
# Florida     1291584.26       3957176.82      1948302.36  1900384.39
# New York    1295316.06       3490882.27      2066239.00  1933859.59

# %%
df.groupby('State')['Profit'].sum()
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %%
plt.bar(expences,df['Profit'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 plt.bar(expences,df['Profit'])
#
# File c:\Users\ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2742, in bar(x, height, width, bottom, align, data, **kwargs)
#    2731 @_copy_docstring_and_deprecators(Axes.bar)
#    2732 def bar(
#    2733     x: float | ArrayLike,
#    (...)
#    2740     **kwargs,
#    2741 ) -> BarContainer:
# -> 2742     return gca().bar(
#    2743         x,
#    2744         height,
#    2745         width=width,
#    2746         bottom=bottom,
#    2747         align=align,
#    2748         **({"data": data} if data is not None else {}),
#    2749         **kwargs,
#    2750     )
#
# ...
